# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

#exportando o dataset 2015
meu_diretorio = "/Users/joaog/Desktop/2semestre/CIENCIAS DOS DADOS/PNAD DOM2015/DOM2015csv"
os.chdir(meu_diretorio)
dados =pd.read_csv('DOM2015.csv',sep=',')

#Exportando o dataset 2014
PNAD2014 ='/Users/joaog/Desktop/2semestre/CIENCIAS DOS DADOS/PNAD DOM2014/DOM2014csv'
os.chdir(PNAD2014)
pnad = pd.read_csv('DOM2014.csv',sep=',')

#Exportando o dataset 2013
PNAD2013 ='/Users/joaog/Desktop/2semestre/CIENCIAS DOS DADOS/PNAD DOM2013/DOM2013csv'
os.chdir(PNAD2013)
pnad1 = pd.read_csv('DOM2013.csv',sep=',')

# %%
#Nomeando as colunas 2015
variavel=dados[(dados.UF<=17) & (dados.V0104<=4) & (dados.V4105<=3)]
coluna = variavel.iloc[:,[2,5,40,49,78]]
coluna.columns=["UF","Entrevista","TV","Internet","Renda"]

#Nomeando as colunas 2014
variavel1=pnad[(pnad.UF<=17) & (pnad.V0104<=4) & (pnad.V4105<=3)]
coluna1 = variavel1.iloc[:,[2,5,40,49,78]]
coluna1.columns=["UF","Entrevista","TV","Internet","Renda"]

#Nomeando as colunas 2013
variavel2=pnad1[(pnad1.UF<=17) & (pnad1.V0104<=4) & (pnad1.V4105<=3)]
coluna2 = variavel2.iloc[:,[2,5,40,49,78]]
coluna2.columns=["UF","Entrevista","TV","Internet","Renda"]

# %%
#nomeando as categorias 2015
coluna.Renda = coluna.Renda.astype('category')
coluna.Renda.cat.categories = ('Sem rendimento','<0,25 SM','de 0,25 a 0,50 SM','de 0,5 a 1 SM','de 1 a 2 SM','de 2 a 3 SM','de 3 a 5 SM','Mais de 5 SM','S/ Declaração')

coluna.UF = coluna.UF.astype('category')
coluna.UF.cat.categories = ('RO','AC','AM','RR','PA','AP','TO')

coluna.Entrevista = coluna.Entrevista.astype('category')
coluna.Entrevista.cat.categories = ('Realizada','Fechada','Recusada','Outra')

coluna.TV = coluna.TV.astype('category')
coluna.TV.cat.categories = ('Sim','Não','Não sabe')

coluna.Internet = coluna.Internet.astype('category')
coluna.Internet.cat.categories = ('Sim','Não')

inteiro=coluna.dropna()
inteiro[coluna.Renda != "S/ Declaração"]
# Out:
# C:\Users\joaog\Anaconda3\lib\site-packages\pandas\core\generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Users\joaog\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        UF Entrevista        TV Internet              Renda
# 0      RO  Realizada       Sim      Não        de 1 a 2 SM
# 3      RO  Realizada       Sim      Sim        de 1 a 2 SM
# 5      RO  Realizada       Sim      Sim        de 2 a 3 SM
# 6      RO  Realizada       Sim      Não  de 0,25 a 0,50 SM
# 7      RO  Realizada       Sim      Não        de 1 a 2 SM
# 8      RO  Realizada       Sim      Sim        de 1 a 2 SM
# 10     RO  Realizada       Sim      Sim        de 2 a 3 SM
# 11     RO  Realizada       Sim      Sim        de 3 a 5 SM
# 13     RO  Realizada       Sim      Sim        de 1 a 2 SM
# 15     RO  Realizada       Sim      Sim      de 0,5 a 1 SM
# 16     RO  Realizada       Não      Não      de 0,5 a 1 SM
# 17     RO  Realizada  Não sabe      Sim      de 0,5 a 1 SM
# 18     RO  Realizada       Sim      Sim        de 1 a 2 SM
# 19     RO  Realizada  Não sabe      Sim      de 0,5 a 1 SM
# 20     RO  Realizada       Não      Sim        de 1 a 2 SM
# 21     RO  Realizada       Não      Não        de 1 a 2 SM
# 23     RO  Realizada       Sim      Sim        de 3 a 5 SM
# 26     RO  Realizada       Não      Não      de 0,5 a 1 SM
# 27     RO  Realizada       Sim      Sim        de 3 a 5 SM
# 28     RO  Realizada       Sim      Sim        de 3 a 5 SM
# 29     RO  Realizada       Não      Sim        de 1 a 2 SM
# 30     RO  Realizada       Sim      Não        de 2 a 3 SM
# 31     RO  Realizada  Não sabe      Sim        de 3 a 5 SM
# 32     RO  Realizada       Não      Sim  de 0,25 a 0,50 SM
# 33     RO  Realizada       Sim      Sim           <0,25 SM
# 35     RO  Realizada       Sim      Não  de 0,25 a 0,50 SM
# 36     RO  Realizada       Sim      Não           <0,25 SM
# 37     RO  Realizada       Sim      Sim      de 0,5 a 1 SM
# 39     RO  Realizada       Sim      Sim           <0,25 SM
# 40     RO  Realizada       Sim      Não      de 0,5 a 1 SM
# ...    ..        ...       ...      ...                ...
# 21404  TO  Realizada       Não      Não        de 1 a 2 SM
# 21405  TO  Realizada       Não      Não           <0,25 SM
# 21406  TO  Realizada       Não      Sim  de 0,25 a 0,50 SM
# 21409  TO  Realizada  Não sabe      Não        de 1 a 2 SM
# 21410  TO  Realizada  Não sabe      Sim      de 0,5 a 1 SM
# 21411  TO  Realizada  Não sabe      Sim        de 1 a 2 SM
# 21415  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21416  TO  Realizada  Não sabe      Não      de 0,5 a 1 SM
# 21417  TO  Realizada  Não sabe      Não      de 0,5 a 1 SM
# 21418  TO  Realizada  Não sabe      Não      de 0,5 a 1 SM
# 21419  TO  Realizada  Não sabe      Sim  de 0,25 a 0,50 SM
# 21420  TO  Realizada  Não sabe      Não           <0,25 SM
# 21421  TO  Realizada  Não sabe      Sim  de 0,25 a 0,50 SM
# 21422  TO  Realizada       Não      Não        de 1 a 2 SM
# 21423  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21424  TO  Realizada       Não      Sim           <0,25 SM
# 21425  TO  Realizada  Não sabe      Sim           <0,25 SM
# 21428  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21429  TO  Realizada       Não      Não        de 1 a 2 SM
# 21430  TO  Realizada       Não      Sim      de 0,5 a 1 SM
# 21431  TO  Realizada  Não sabe      Não        de 1 a 2 SM
# 21432  TO  Realizada       Não      Sim  de 0,25 a 0,50 SM
# 21433  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21434  TO  Realizada       Não      Sim      de 0,5 a 1 SM
# 21435  TO  Realizada       Sim      Não      de 0,5 a 1 SM
# 21436  TO  Realizada       Não      Sim  de 0,25 a 0,50 SM
# 21438  TO  Realizada       Não      Sim        de 1 a 2 SM
# 21439  TO  Realizada  Não sabe      Sim  de 0,25 a 0,50 SM
# 21440  TO  Realizada  Não sabe      Não      de 0,5 a 1 SM
# 21441  TO  Realizada  Não sabe      Sim  de 0,25 a 0,50 SM
#
# [12677 rows x 5 columns]

# %%
#Nomeando as variaveis 2014
coluna1.Renda = coluna1.Renda.astype('category')
coluna1.Renda.cat.categories = ('Sem rendimento','<0,25 SM','de 0,25 a 0,50 SM','de 0,5 a 1 SM','de 1 a 2 SM','de 2 a 3 SM','de 3 a 5 SM','Mais de 5 SM','S/ Declaração')

coluna1.UF = coluna1.UF.astype('category')
coluna1.UF.cat.categories = ('RO','AC','AM','RR','PA','AP','TO')

coluna1.Entrevista = coluna1.Entrevista.astype('category')
coluna1.Entrevista.cat.categories = ('Realizada','Fechada','Recusada','Outra')

coluna1.TV = coluna1.TV.astype('category')
coluna1.TV.cat.categories = ('Sim','Não','Não sabe')

coluna1.Internet = coluna1.Internet.astype('category')
coluna1.Internet.cat.categories = ('Sim','Não')


inteiro=coluna1.dropna()
inteiro[coluna1.Renda != "S/ Declaração"]
# Out:
# C:\Users\joaog\Anaconda3\lib\site-packages\pandas\core\generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Users\joaog\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        UF Entrevista   TV Internet              Renda
# 0      RO  Realizada  Sim      Não      de 0,5 a 1 SM
# 1      RO  Realizada  Sim      Sim        de 1 a 2 SM
# 2      RO  Realizada  Sim      Não      de 0,5 a 1 SM
# 3      RO  Realizada  Sim      Sim        de 2 a 3 SM
# 4      RO  Realizada  Não      Sim        de 1 a 2 SM
# 5      RO  Realizada  Sim      Não        de 1 a 2 SM
# 6      RO  Realizada  Sim      Sim        de 3 a 5 SM
# 7      RO  Realizada  Não      Sim        de 1 a 2 SM
# 9      RO  Realizada  Sim      Sim        de 3 a 5 SM
# 10     RO  Realizada  Sim      Sim        de 1 a 2 SM
# 12     RO  Realizada  Não      Sim        de 1 a 2 SM
# 13     RO  Realizada  Não      Sim        de 1 a 2 SM
# 14     RO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 16     RO  Realizada  Sim      Sim      de 0,5 a 1 SM
# 17     RO  Realizada  Não      Sim        de 1 a 2 SM
# 18     RO  Realizada  Sim      Sim        de 1 a 2 SM
# 19     RO  Realizada  Não      Não        de 1 a 2 SM
# 20     RO  Realizada  Sim      Sim        de 2 a 3 SM
# 21     RO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 22     RO  Realizada  Sim      Sim        de 2 a 3 SM
# 23     RO  Realizada  Não      Sim        de 3 a 5 SM
# 24     RO  Realizada  Não      Sim        de 3 a 5 SM
# 25     RO  Realizada  Sim      Sim        de 1 a 2 SM
# 26     RO  Realizada  Não      Sim        de 2 a 3 SM
# 27     RO  Realizada  Não      Não        de 1 a 2 SM
# 28     RO  Realizada  Não      Sim        de 1 a 2 SM
# 30     RO  Realizada  Não      Não           <0,25 SM
# 31     RO  Realizada  Sim      Não        de 1 a 2 SM
# 32     RO  Realizada  Sim      Sim  de 0,25 a 0,50 SM
# 33     RO  Realizada  Não      Não        de 1 a 2 SM
# ...    ..        ...  ...      ...                ...
# 21393  TO  Realizada  Sim      Sim      de 0,5 a 1 SM
# 21396  TO  Realizada  Não      Não        de 1 a 2 SM
# 21398  TO  Realizada  Não      Sim  de 0,25 a 0,50 SM
# 21399  TO  Realizada  Não      Sim      de 0,5 a 1 SM
# 21400  TO  Realizada  Sim      Sim  de 0,25 a 0,50 SM
# 21402  TO  Realizada  Não      Sim        de 2 a 3 SM
# 21403  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21404  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21405  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21406  TO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 21407  TO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 21408  TO  Realizada  Não      Sim  de 0,25 a 0,50 SM
# 21409  TO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 21411  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21412  TO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 21413  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21414  TO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 21416  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21417  TO  Realizada  Não      Não  de 0,25 a 0,50 SM
# 21419  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21420  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21421  TO  Realizada  Sim      Sim      de 0,5 a 1 SM
# 21422  TO  Realizada  Não      Sim  de 0,25 a 0,50 SM
# 21423  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21424  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21426  TO  Realizada  Sim      Não  de 0,25 a 0,50 SM
# 21427  TO  Realizada  Sim      Não        de 1 a 2 SM
# 21428  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21429  TO  Realizada  Não      Não      de 0,5 a 1 SM
# 21430  TO  Realizada  Não      Não      de 0,5 a 1 SM
#
# [12443 rows x 5 columns]

# %%
#Nomeando as variaveis 2013
coluna2.Renda = coluna2.Renda.astype('category')
coluna2.Renda.cat.categories = ('Sem rendimento','<0,25 SM','de 0,25 a 0,50 SM','de 0,5 a 1 SM','de 1 a 2 SM','de 2 a 3 SM','de 3 a 5 SM','Mais de 5 SM','S/ Declaração')

coluna2.UF = coluna2.UF.astype('category')
coluna2.UF.cat.categories = ('RO','AC','AM','RR','PA','AP','TO')

coluna2.Entrevista = coluna2.Entrevista.astype('category')
coluna2.Entrevista.cat.categories = ('Realizada','Fechada','Recusada','Outra')

coluna2.TV = coluna2.TV.astype('category')
coluna2.TV.cat.categories = ('Sim','Não','Não sabe')

coluna2.Internet = coluna2.Internet.astype('category')
coluna2.Internet.cat.categories = ('Sim','Não')


inteiro=coluna2.dropna()
inteiro[coluna2.Renda != "S/ Declaração"]
# Out:
# C:\Users\joaog\Anaconda3\lib\site-packages\pandas\core\generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# C:\Users\joaog\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        UF Entrevista        TV Internet              Renda
# 2      RO  Realizada       Não      Não      de 0,5 a 1 SM
# 4      RO  Realizada       Não      Não  de 0,25 a 0,50 SM
# 5      RO  Realizada       Sim      Não      de 0,5 a 1 SM
# 6      RO  Realizada       Sim      Não      de 0,5 a 1 SM
# 7      RO  Realizada       Sim      Sim        de 1 a 2 SM
# 8      RO  Realizada       Sim      Sim        de 2 a 3 SM
# 9      RO  Realizada       Não      Sim        de 1 a 2 SM
# 10     RO  Realizada       Sim      Não  de 0,25 a 0,50 SM
# 11     RO  Realizada       Sim      Não  de 0,25 a 0,50 SM
# 12     RO  Realizada       Não      Não        de 1 a 2 SM
# 15     RO  Realizada       Sim      Não      de 0,5 a 1 SM
# 17     RO  Realizada       Não      Sim        de 1 a 2 SM
# 18     RO  Realizada       Não      Não        de 1 a 2 SM
# 19     RO  Realizada       Não      Não      de 0,5 a 1 SM
# 20     RO  Realizada       Não      Não      de 0,5 a 1 SM
# 21     RO  Realizada       Não      Não        de 2 a 3 SM
# 22     RO  Realizada       Não      Sim        de 2 a 3 SM
# 24     RO  Realizada       Não      Sim        de 3 a 5 SM
# 25     RO  Realizada       Não      Não      de 0,5 a 1 SM
# 26     RO  Realizada       Não      Não  de 0,25 a 0,50 SM
# 28     RO  Realizada       Sim      Sim        de 1 a 2 SM
# 29     RO  Realizada       Sim      Sim        de 1 a 2 SM
# 30     RO  Realizada       Não      Não           <0,25 SM
# 31     RO  Realizada       Sim      Sim        de 2 a 3 SM
# 32     RO  Realizada       Não      Sim        de 2 a 3 SM
# 33     RO  Realizada  Não sabe      Não      de 0,5 a 1 SM
# 34     RO  Realizada  Não sabe      Sim        de 2 a 3 SM
# 35     RO  Realizada  Não sabe      Não      de 0,5 a 1 SM
# 36     RO  Realizada  Não sabe      Sim        de 1 a 2 SM
# 38     RO  Realizada  Não sabe      Não      de 0,5 a 1 SM
# ...    ..        ...       ...      ...                ...
# 21183  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21185  TO  Realizada       Não      Sim  de 0,25 a 0,50 SM
# 21186  TO  Realizada       Sim      Não  de 0,25 a 0,50 SM
# 21187  TO  Realizada       Não      Não  de 0,25 a 0,50 SM
# 21188  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21189  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21190  TO  Realizada       Não      Não           <0,25 SM
# 21192  TO  Realizada       Não      Não           <0,25 SM
# 21193  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21194  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21195  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21196  TO  Realizada       Não      Não  de 0,25 a 0,50 SM
# 21197  TO  Realizada       Não      Não        de 2 a 3 SM
# 21198  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21200  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21201  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21202  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21203  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21204  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21205  TO  Realizada       Não      Sim      de 0,5 a 1 SM
# 21206  TO  Realizada       Não      Não           <0,25 SM
# 21207  TO  Realizada       Não      Não  de 0,25 a 0,50 SM
# 21208  TO  Realizada       Não      Não      de 0,5 a 1 SM
# 21209  TO  Realizada       Não      Sim      de 0,5 a 1 SM
# 21210  TO  Realizada       Não      Não        de 1 a 2 SM
# 21213  TO  Realizada       Não      Não  de 0,25 a 0,50 SM
# 21214  TO  Realizada       Não      Não  de 0,25 a 0,50 SM
# 21215  TO  Realizada       Não      Sim        de 3 a 5 SM
# 21217  TO  Realizada       Não      Sim        de 2 a 3 SM
# 21218  TO  Realizada       Sim      Não      de 0,5 a 1 SM
#
# [12160 rows x 5 columns]
